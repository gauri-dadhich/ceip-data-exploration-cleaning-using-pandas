# %% [markdown]
# # **Objective:-**
# Perform basic data exploration and cleaning using Python Pandas on an Ecommerce Products Dataset.

# %% [markdown]
# The dataset contains many files so i've performed operations on Combined_dataset.csv

# %%
import pandas as pd

# %%
df=pd.read_csv("Combined_dataset.csv")

# %% [markdown]
# Original Dataset

# %%
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %% [markdown]
# Exploring dataset

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
df.shape
# Out:
# (1000, 24)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
df.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %%
df.describe()
# Out:
#          product_id     rating  ratings_count  initial_price    discount
# count  1.000000e+03  1000.0000    1000.000000     1000.00000  879.000000
# mean   1.713437e+07     3.6215      76.691000     2723.24100   53.503982
# std    3.813766e+06     1.3744     241.114263     2408.69736   18.029201
# min    5.868460e+05     0.0000       0.000000      249.00000    1.000000
# 25%    1.511501e+07     3.7000       7.000000     1399.00000   44.000000
# 50%    1.820890e+07     4.1000      17.000000     1999.00000   56.000000
# 75%    1.902737e+07     4.3000      58.000000     3299.00000   66.000000
# max    2.274707e+07     5.0000    4441.000000    22199.00000   88.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   object
#  2   product_description     1000 non-null   object
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   object
#  8   currency                1000 non-null   object
#  9   images                  1000 non-null   object
#  10  delivery_options        1000 non-null   object
#  11  product_details         1000 non-null   object
#  12  breadcrumbs             1000 non-null   object
#  13  product_specifications  1000 non-null   object
# ...

# %% [markdown]
# 3)Identifying & Handle Missing values

# %%
df.isnull().sum() #count no of true null values
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %% [markdown]
# using **fillna** as there are many missing values so using **dropna** will remove many rows containing missing values that's too much data loss
# hence using **fillna**

# %%
df.fillna(0,inplace=True) #inplace will change the original dataset permanently

# %% [markdown]
# #4)Basic operations
# filtering rows Based on:
#
# 1)rating
# 2)discount

# %%
rating=df[df["rating"]>4]
rating.shape
# Out:
# (533, 24)

# %%
print(df["discount"].dtype)
# Out:
# float64

# %%
discount=df[df["discount"]>50]
discount
# Out:
#      product_id                title  \
# 0       8376765          Lino Perros
# 2      17633752                Lavie
# 3       1376949               F Gear
# 6      19851824           AVI Living
# 7      18602872              My Room
# ..          ...                  ...
# 988     8076639    French Connection
# 989    21948792  Adwitiya Collection
# 990     9053317            TIMESMITH
# 991     2466414         Daniel Klein
# 994     8481603    French Connection
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 6            Grey Solid 500 GSM Pure Cotton Bath Towel     4.0              5
# 7    Yellow & Green Floral 140 TC King Bedsheet wit...     4.7             10
# ...

# %% [markdown]
# Column Filter

# %%
select_col=df[["title","rating","discount"]]
select_col.head()
# Out:
#             title  rating  discount
# 0     Lino Perros     3.8      58.0
# 1  Tommy Hilfiger     4.5      35.0
# 2           Lavie     4.4      65.0
# 3          F Gear     4.4      52.0
# 4       MYTRIDENT     4.7      17.0

# %%
df[["title","rating","discount"]]
# Out:
#               title  rating  discount
# 0       Lino Perros     3.8      58.0
# 1    Tommy Hilfiger     4.5      35.0
# 2             Lavie     4.4      65.0
# 3            F Gear     4.4      52.0
# 4         MYTRIDENT     4.7      17.0
# ..              ...     ...       ...
# 995           KREDO     3.5      50.0
# 996           GUESS     5.0      45.0
# 997        GIORDANO     2.8      50.0
# 998        Fastrack     4.3      20.0
# 999         BOLDFIT     3.8      31.0
#
# [1000 rows x 3 columns]

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# As quantity coloumn is not given we'll create on as learned in the last module

# %%
# New column with value 1
df["quantity"] = [1 for i in range(len(df))]

# %%
def total(price):
    return price*1

# %%
df["total_amount"] = df["initial_price"].apply(total)

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ... seller_name  \
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category', 'quantity', 'total_amount'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 26)

# %%
df[["initial_price","quantity","total_amount"]].head()
# Out:
#    initial_price  quantity  total_amount
# 0           3995         1          3995
# 1           2899         1          2899
# 2           2999         1          2999
# 3           1675         1          1675
# 4           2899         1          2899

# %%
df.to_csv("cleaned dataset")

# %% [markdown]
# # Brief Summary
#
# * As the provided ZIP file contained multiple CSV files, one combined dataset file was selected for analysis and cleaning.
#
# * The dataset was loaded into a Pandas DataFrame and basic data exploration was performed using functions such as `head()`, `tail()`, `shape`, `columns`, and `dtypes`. The selected dataset contained approximately **(1000, 24)** rows and columns.
#
# * Missing values were identified using `isnull().sum()`. Since the dataset contained a large number of missing values (around **2518**), `fillna()` was used instead of `dropna()` to avoid excessive loss of data. Missing values were replaced with **0**.
#
# * Basic data operations were performed, including filtering rows based on conditions such as **discount greater than 50%** and **rating greater than 4**. Required columns were also selected for observation.
#
# * Duplicate records were identified and removed to improve data quality.
#
# * As covered in the last module, new columns were created using functions and DataFrame operations. Since the dataset did not contain a `quantity` column, a new `quantity` column was created and then used to create the derived column `total_amount`.
#
# * Finally, the cleaned dataset was exported and saved as **cleaned_ecommerce_dataset.csv** for further analysis and use.
# * finally now there are (1000,26) columns as 2 new columns
